# %%
#Importamos la libreria de pandas
import pandas as pd
import numpy as np
import io

# %%
#Leemos el contenido del archivo 
#df = pd.read_csv('Exportaciones.csv', index_col=0)
df = pd.read_csv('Exportaciones.csv')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13203 entries, 0 to 13202
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   iso3            13203 non-null  object
#  1   year            13203 non-null  int64
#  2   sector_GMatrix  13203 non-null  object
#  3   g_primaryagr    13203 non-null  float64
#  4   g_otherprim     13203 non-null  float64
#  5   g_energy        13203 non-null  float64
#  6   g_procfoods     13203 non-null  float64
#  7   g_bevtobacco    13203 non-null  float64
#  8   g_textiles      13203 non-null  float64
#  9   g_clothing      13203 non-null  float64
#  10  g_leather       13203 non-null  float64
#  11  g_lumber        13203 non-null  float64
#  12  g_paperpub      13203 non-null  float64
#  13  g_chemicals     13203 non-null  float64
#  14  g_nonmetmin     13203 non-null  float64
#  15  g_metals        13203 non-null  float64
#  16  g_fabmetals     13203 non-null  float64
# ...

# %%
#Filtros básicos para variables cualitativas 
#Filtro A1
filtroa1=df[df["iso3"] == "alb"]
#filtroa1
#FILTROS BÁSCIOS PARA VARIABLES CUANTI
#Filtro A2
filtroA2=df[df["h_insurance"]>= 0.5]
#filtroA2
filtroAfinal=df[(df["h_insurance"] > 0.5) & (df["iso3"] == "alb")]
filtroAfinal

# %%
filtroBfinal=df[(df["g_procfoods"] > 7) & (df["sector_GMatrix"] == "insurance")]
filtroBfinal

# %%
filtroCfinal=df[(df["year"] >= 1997) & (df["year"] <= 2005)]
filtroCfinal

# %%
filtroDfinal=df[(df["VXsharefwd"] > 0.5) & (df["VXsharebwd"] < 0.5)]
filtroDfinal

# %%
E1= df[(df["iso3"] == "kor") | (df["iso3"]=="tha")|(df["iso3"] == "tha")|(df["iso3"] == "phl")|(df["iso3"]== "ven")|(df["iso3"]=="deu")]
E1
E2=E1[(df["g_textiles"] > 1) & (df["g_clothing"] < 1)]
E2
# Out:
# /var/folders/q1/f43_jg2540b1tkfdg5w6_rgc0000gn/T/ipykernel_74188/510823130.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   E2=E1[(df["g_textiles"] > 1) & (df["g_clothing"] < 1)]
# Empty DataFrame
# ...

# %%
filtroFfinal=df[(df["year"] == 2004) & (df["h_oservices"] > 10)]
filtroFfinal
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 3833  alb  2004      oservices        0.2913       0.1102    0.1467
# 3860  are  2004      oservices        0.1888       0.0584   15.8087
# 3885  arg  2004         obsict      251.8390       6.4964   83.9202
# 3887  arg  2004      oservices      202.6470       5.3857   76.9778
# 3914  arm  2004      oservices        2.5615       1.0366    0.6777
# ...   ...   ...            ...           ...          ...       ...
# 6827  zaf  2004      insurance      235.5240     133.2500  132.4490
# 6828  zaf  2004         obsict      272.1790     233.8180  151.5080
# 6830  zaf  2004      oservices       63.6928      25.9981    5.6810
# 6857  zmb  2004      oservices        0.5410       1.0682    5.1792
# 6884  zwe  2004      oservices        9.4795       0.9173    0.5526
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 3833       0.3305        0.0156      0.1665      0.1973  ...     0.0336
# ...

# %%
filtroGfinal=df[~(df["sector_GMatrix"] == "machinery")]
filtroGfinal
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 2      alb  1997         energy       12.8071       3.0441  195.5730
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
filtroHfinal=df[~(df["DXshare"] > 0.5)]
filtroHfinal
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# 5      alb  1997       textiles        0.0082       0.0004    0.0028
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
filtroIfinal=df[(df["h_oconsumer"] == 0.02) | (df["h_obsict"] > 10)]
filtroIfinal
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 51     arg  1997         obsict      172.1130       1.8889   125.9700
# 56     aus  1997         energy      264.1910     327.3620  8225.6200
# 63     aus  1997       paperpub       79.4958      42.9939    27.4799
# 71     aus  1997          water       65.8972      26.7741    29.4982
# 73     aus  1997   distribution      560.1380     330.4000   166.1190
# ...    ...   ...            ...           ...          ...        ...
# 13175  zmb  2011      oservices        0.9600       2.9100     9.7900
# 13187  zwe  2011      nonmetmin        0.4400       0.7200     0.2000
# 13198  zwe  2011        finance       15.7700       0.3200     0.2900
# 13200  zwe  2011         obsict       18.5100       0.4300     0.3700
# 13202  zwe  2011      oservices       12.1400       1.0900     0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...
